# %% [markdown]
# <a href="https://colab.research.google.com/github/vyaman/python-dersleri/blob/main/matploit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xnoktalari = np.array([0, 6])
ynoktalari = np.array([0, 250])

plt.plot(xnoktalari, ynoktalari)
plt.show()
